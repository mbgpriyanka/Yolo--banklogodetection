# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !unzip "/content/drive/My Drive/AKIF/logodetection_yolo/darknet.zip"
# Out:
# Archive:  /content/drive/My Drive/AKIF/logodetection_yolo/darknet.zip
#    creating: darknet/
#   inflating: darknet/.gitignore
#    creating: darknet/backup/
#    creating: darknet/cfg/
#   inflating: darknet/cfg/alexnet.cfg
#   inflating: darknet/cfg/cifar.cfg
#   inflating: darknet/cfg/cifar.test.cfg
#   inflating: darknet/cfg/coco.data
#   inflating: darknet/cfg/combine9k.data
#   inflating: darknet/cfg/darknet.cfg
#   inflating: darknet/cfg/darknet19.cfg
#   inflating: darknet/cfg/darknet19_448.cfg
#   inflating: darknet/cfg/darknet53.cfg
#   inflating: darknet/cfg/darknet53_448.cfg
#   inflating: darknet/cfg/darknet9000.cfg
#   inflating: darknet/cfg/densenet201.cfg
#   inflating: darknet/cfg/extraction.cfg
#   inflating: darknet/cfg/extraction.conv.cfg
#   inflating: darknet/cfg/extraction22k.cfg
#   inflating: darknet/cfg/go.cfg
#   inflating: darknet/cfg/go.test.cfg
#   inflating: darknet/cfg/gru.cfg
#   inflating: darknet/cfg/imagenet1k.data
# ...

# %%
# %cd /content/darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:957:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
#!rm /content/darknet/backup -r
#!ln -s /content/drive/'MyDrive'/logodetection_yolo/YoloV3_weights/backup /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (655 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/test.txt
# !dos2unix ./data/labelled_data.data
# !dos2unix ./data/classes.names
# !dos2unix ./cfg/yolov3_custom_banklogo.cfg
# Out:
# /bin/bash: dos2unix: command not found
# /bin/bash: dos2unix: command not found
# /bin/bash: dos2unix: command not found
# /bin/bash: dos2unix: command not found
# /bin/bash: dos2unix: command not found

# %%
# model training
# %cd /content/darknet
# !./darknet detector train data/labelled_data.data cfg/yolov3_custom_banklogo.cfg darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 106 Avg IOU: 0.215250, Class: 0.615143, Obj: 0.005118, No Obj: 0.001560, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.007083, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.429984, Class: 0.536361, Obj: 0.042851, No Obj: 0.003528, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.275056, Class: 0.351612, Obj: 0.001846, No Obj: 0.001585, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.007185, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.003624, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.237085, Class: 0.551641, Obj: 0.004141, No Obj: 0.001920, .5R: 0.000000, .75R: 0.000000,  count: 2
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.006759, .5R: -nan, .75R: -nan,  count: 0
# ...

# %%
# copy pre-trained weight from your Drive to folder darknet
#!cp /content/drive/'My Drive'/YOLOv3_files/yolov3_900.weights /content/darknet

# train annd save loss result in log.txt
#%cd /content/darknet
#!./darknet detector train data/labelled_data.data.data cfg/yolov3_custom_banklogo.cfg yolov3_900.weights | tee log.txt
# Out:
# cp: cannot stat '/content/drive/My Drive/YOLOv3_files/yolov3_900.weights': No such file or directory
# /content/drive/My Drive/AKIF/logodetection_yolo/backup
# Couldn't open file: data/yolo.data

# %%
# !./darknet detector map /data/labelled_data.data cfg/yolov3_custom_banklogo.cfg /content/drive/MyDrive/AKIF/logodetection_yolo/YoloV3_weights/yolov3_custom_banklogo_300.weights

# %%
# !cp /content/darknet/data/classes.names /content/darknet/classes.names
# !cp /content/darknet/data/train.txt /content/darknet/train.txt
# !cp /content/darknet/data/test.txt /content/darknet/test.txt

# %%
# !./darknet detector test data/labelled_data.data cfg/yolov3_custom_banklogo.cfg /content/drive/MyDrive/AKIF/logodetection_yolo/YoloV3_weights/yolov3_custom_banklogo_300.weights  /content/drive/MyDrive/AKIF/logodetection_yolo/YoloV3_weights/Bankimages/a1-1.jpg
# Out:
# Couldn't open file: data/classes.names
